# %% [markdown]
# <a href="https://colab.research.google.com/github/polinaopeo-boop/database/blob/main/%D0%A1%D0%BF%D0%B8%D1%81%D0%BE%D0%BA_%D0%B7_%D0%B1%D0%B0%D0%B7%D0%B8_%D0%B4%D0%B0%D0%BD%D0%B8%D1%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

file_path = 'база даних.csv'
df = pd.read_csv(file_path, encoding='utf-8-sig')

try:
    df = pd.read_csv(file_path)
    plants_list = df.to_dict(orient='records')

    print(f"✅ Усього в базі: {len(plants_list)} рослин\n")

    # Тепер виводимо весь список без обмежень
    for plant in plants_list:
        print(f" {plant['Назва (Title)']} ({plant['Категорія']}) — {plant['Ціна']} грн")

except Exception as e:
    print(f"❌ Помилка: {e}")
# Out:
# ✅ Усього в базі: 25 рослин
#
#  Томат "Черрі" (Овочі) — 25 грн
#  Перець "Каліфорнійське чудо" (Овочі) — 30 грн
#  Огірок "Роднічок" (Овочі) — 20 грн
#  Баклажан "Алмаз" (Овочі) — 28 грн
#  Капуста "Агресор" (Овочі) — 15 грн
#  Броколі "Лінда" (Овочі) — 32 грн
#  Кавун "Огоньок" (Баштанні) — 35 грн
#  Диня "Амал" (Баштанні) — 40 грн
#  Полуниця "Альбіон" (Ягоди) — 45 грн
#  Малина "Полана" (Ягоди) — 55 грн
#  Лохина "Блюкроп" (Ягоди) — 120 грн
#  Виноград "Аркадія" (Фрукти) — 85 грн
#  Гарбуз "Хоккайдо" (Овочі) — 22 грн
#  Кабачок "Цукіні" (Овочі) — 18 грн
#  Салат "Айсберг" (Зелень) — 12 грн
#  Шпинат "Матадор" (Зелень) — 10 грн
#  Базилік "Фіолетовий" (Зелень) — 15 грн
#  Селера "Пан" (Зелень) — 20 грн
#  Цибуля "Халцедон" (Овочі) — 10 грн
#  Часник "Любаша" (Овочі) — 15 грн
#  Суниця "Лісова" (Ягоди) — 38 грн
#  Ожина "Натчез" (Ягоди) — 70 грн
#  Лимон "Мейєра" (Екзотика) — 250 грн
#  Інжир "Кримський" (Екзотика) — 180 грн
#  Гранат "Кримський" (Екзотика) — 210 грн
